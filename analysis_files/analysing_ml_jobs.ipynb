# %% [markdown]
# ### We have separated jobs according to job_role in different csv file. In this Notebook we will analyse the ML & AI jobs.

# %%
import numpy as np
import pandas as pd
import os
print(os.listdir('../separated_jobs'))
# Out:
# ['.ipynb_checkpoints', '3d_specialist.csv', 'academic_professor.csv', 'ai_engineer.csv', 'analyst_roles.csv', 'app_developer.csv', 'artificial_intelligence_researcher.csv', 'automation_engineer.csv', 'backend-developer.csv', 'blockchain_developer.csv', 'business_analyst.csv', 'c#_developer.csv', 'c++_developer.csv', 'cloud_engineer.csv', 'content_writer.csv', 'cybersecurity_specialist.csv', 'data_analyst.csv', 'data_base_administrator.csv', 'data_scientist.csv', 'developer_roles.csv', 'devops_engineer.csv', 'digital_marketing_specialist.csv', 'electronics_engineer.csv', 'firmware_engineer.csv', 'freelancer.csv', 'front-end_developer.csv', 'full-stack_developer.csv', 'game_developer.csv', 'graphics_designer.csv', 'hardware_engineer.csv', 'integration_engineer.csv', 'it_specialist.csv', 'java_developer.csv', 'lead_engineer.csv', 'machine_learning_engineer.csv', 'manager_roles.csv', 'mechanical_engineer.csv', 'network_engineer.csv', 'other.csv', 'product_manager.csv', 'python_developer.csv', 'quality-assurance_engineer.csv', 'researcher.csv', 'robot_engineer.csv', 'site-reliability_engineer.csv', 'social_media_manager.csv', 'software_engineer.csv', 'support_engineer.csv', 'system_engineer.csv', 'test_engineer.csv', 'tutor_roles.csv', 'ux_designer.csv']

# %% [markdown]
# ### General View of DataFrame

# %%
df_machine_learning = pd.read_csv('../separated_jobs/machine_learning_engineer.csv')
df_ai = pd.read_csv('../separated_jobs/ai_engineer.csv')
df_ai_researcher = pd.read_csv('../separated_jobs/artificial_intelligence_researcher.csv')

# %%
df_machine_learning.head()
# Out:
#                                 company_name  \
# 0                               Recode Minds
# 1                                  Microsoft
# 2                         Club Malwa pvt ltd
# 3                            Meslova Systems
# 4  Council for Robotics & Automation (AICRA)
#
#                                             job_role job_location  salary_pa  \
# 0       Research Associate – Artificial Intelligence    Hyderābād   550000.0
# 1               Researcher - Machine Learning and AI    Bengaluru   700000.0
# 2                      Senior Deep Learning Engineer       Mohali   135000.0
# 3  Artificial Intelligence (AI) Researchers and D...    Hyderābād   400000.0
# 4  Director - National Mission of Artificial Inte...        Delhi  4800000.0
#
#                                               skills  company_rating  \
# 0           TensorFlow, MATLAB, Data mining, R, Math             NaN
# 1  Machine learning, Natural language processing, AI             4.2
# 2  TensorFlow, Image processing, Azure, Big data,...             NaN
# 3   TensorFlow, React, Calculus, Encryption, English             2.8
# 4  English, Business development, Presentation sk...             3.9
#
#        standardized_job_role
# 0  Machine Learning Engineer
# 1  Machine Learning Engineer
# 2  Machine Learning Engineer
# 3  Machine Learning Engineer
# 4  Machine Learning Engineer

# %%
df_machine_learning = pd.concat([df_machine_learning, df_ai], ignore_index = False)
df_machine_learning = pd.concat([df_machine_learning, df_ai_researcher], ignore_index = False)

# %% [markdown]
# ### Filling null values

# %%
df_machine_learning.isnull().sum()
# Out:
# company_name               0
# job_role                   0
# job_location               0
# salary_pa                  0
# skills                     0
# company_rating           118
# standardized_job_role      0
# dtype: int64

# %%
df_machine_learning[df_machine_learning['salary_pa'] == 0]
# Out:
#                                           company_name  \
# 5                                          Crypto Mize
# 6                                    Tesseract Imaging
# 8                                               Google
# 11   Narsee Monjee Institute of Management Studies ...
# 14                            Thermo Fisher Scientific
# ..                                                 ...
# 97                                      i2e Consulting
# 98                                             AryaXAI
# 100                                           Sasefied
# 0                                    BigSpire Software
# 4                                                Dolby
#
#                                               job_role job_location  \
# 5                       Artificial Intelligence Expert        Delhi
# 6    Associate Director of Artificial Intelligence ...  Maharashtra
# 8        Machine Learning Research Engineer, Health AI    Bengaluru
# 11   Associate Professor/Assistant Professor-MPSTME...       Mumbai
# 14                Engineer II, Artificial Intelligence    Bengaluru
# ..                                                 ...          ...
# 97                                         AI Engineer       Remote
# 98                                         AI Engineer       Mumbai
# 100                              AI Development Intern       Remote
# 0        Artificial Intelligence Researcher - Freshers        India
# 4                Senior AI Researcher - Multimodal Lab    Bengaluru
#
#      salary_pa                                             skills  \
# 5          0.0  Microsoft Powerpoint, Microsoft Word, Computer...
# 6          0.0  OS Kernels, Machine learning, APIs, Data scien...
# 8          0.0  TensorFlow, Data mining, Data structures, Rese...
# 11         0.0  Image processing, Computer vision, Research, D...
# 14         0.0      Azure, React, Kubernetes, Java, Microservices
# ..         ...                                                ...
# 97         0.0  TensorFlow, Azure, Google Cloud Platform, Java...
# 98         0.0    TensorFlow, Machine learning, Deep learning, AI
# 100        0.0    Azure, Node.js, React, Mobile applications, AWS
# 0          0.0          Analysis skills, AI, Communication skills
# 4          0.0  TensorFlow, Machine learning, Deep learning, N...
#
#      company_rating               standardized_job_role
# 5               4.8           Machine Learning Engineer
# 6               4.2           Machine Learning Engineer
# 8               4.3           Machine Learning Engineer
# 11              4.1           Machine Learning Engineer
# 14              3.6           Machine Learning Engineer
# ..              ...                                 ...
# 97              4.2                         AI Engineer
# 98              NaN                         AI Engineer
# 100             NaN                         AI Engineer
# 0               3.9  Artificial Intelligence Researcher
# 4               3.9  Artificial Intelligence Researcher
#
# [100 rows x 7 columns]

# %%
df_machine_learning.sample(20)
# Out:
#                                 company_name  \
# 229                    Hexafold technologies
# 200                                   Google
# 43                            DataAnnotation
# 115                                    Apple
# 250                             OrangePeople
# 1                              Digital Green
# 72                                  DeepEdge
# 228                Kotai Electronics Pvt Ltd
# 126                                Jan Elaaj
# 121  American Express Global Business Travel
# 60                            DataAnnotation
# 246                                SNDK Corp
# 249                     Impetus Technologies
# 44               vagarious solutions pvt.ltd
# 87                                       RP2
# 59                            DataAnnotation
# 261                   FiftyFive Technologies
# 152                Inavan India Technologies
# 156                      Max Secure Software
# 163                            JPMorganChase
#
#                                               job_role job_location  \
# 229                           LLaMA and AI/ML Engineer       Mumbai
# 200  Software Engineer III, Machine Learning, Googl...    Bengaluru
# 43             Bilingual Community Manager- AI Trainer        India
# 115  Machine Learning Research Engineer, Apple Inte...    Bengaluru
# 250                    OP046 - Artificial Intelligence    Hyderābād
# 1                                        AI Researcher    Bengaluru
# 72                            Machine Learning Interns    Hyderābād
# 228                          Machine Learning Engineer        India
# 126                        Machine Learning Enthusiast        India
# 121                       Machine Learning Engineer II      Gurgaon
# 60             Food Industry Professional - AI Trainer   Chandigarh
# 246              Machine Learning Engineer | SNDK CORP    Ahmedabad
# 249                                     AI/ML Engineer    Bengaluru
# 44                                      AI/ML Engineer    Hyderābād
# 87                  Prompt Engineering & Gen AI intern       Cochin
# 59               Food and Beverage Expert - AI Trainer        India
# 261                          Machine Learning Engineer       Jaipur
# 152                         Machine Learning Engineers       Cochin
# 156                          Machine Learning Engineer         Pune
# 163        Fraud Modeling - Machine Learning Associate    Bengaluru
#
#      salary_pa                                             skills  \
# 229   650000.0  TensorFlow, Azure, AWS, Analysis skills, Machi...
# 200        0.0  TensorFlow, Data structures, System design, Ma...
# 43   1810809.0  Bilingual, Writing skills, English, Research, ...
# 115        0.0  TensorFlow, Objective-C, OOP, Presentation ski...
# 250   650000.0  Project management, Machine learning, Deep lea...
# 1     950000.0  TensorFlow, Image processing, Computer vision,...
# 72         0.0                  Microsoft Excel, Machine learning
# 228   240000.0  TensorFlow, CI/CD, Image processing, Azure, Ku...
# 126   450000.0  Statistics, Data modeling, Data structures, Ja...
# 121   700000.0  TensorFlow, Image processing, Kubernetes, SQL,...
# 60   1810809.0  Bilingual, Writing skills, English, Research, ...
# 246        0.0  TensorFlow, Statistics, Power BI, Azure, Googl...
# 249   650000.0     TensorFlow, Statistics, Azure, Big data, Spark
# 44         0.0          TensorFlow, Azure, Kubernetes, R, Tableau
# 87     60000.0                           AI, Communication skills
# 59   1810809.0  Bilingual, Writing skills, English, Research, ...
# 261   650000.0  TensorFlow, Power BI, Azure, Kubernetes, Softw...
# 152   550000.0  TensorFlow, Image processing, Computer vision,...
# 156        0.0  Relational databases, Databases, Statistical a...
# 163  1200000.0              TensorFlow, Big data, Spark, SQL, AWS
#
#      company_rating               standardized_job_role
# 229             NaN           Machine Learning Engineer
# 200             4.3           Machine Learning Engineer
# 43              3.8                         AI Engineer
# 115             4.1           Machine Learning Engineer
# 250             4.0           Machine Learning Engineer
# 1               3.8  Artificial Intelligence Researcher
# 72              4.6           Machine Learning Engineer
# 228             NaN           Machine Learning Engineer
# 126             NaN           Machine Learning Engineer
# 121             4.1           Machine Learning Engineer
# 60              3.8                         AI Engineer
# 246             4.3           Machine Learning Engineer
# 249             4.1           Machine Learning Engineer
# 44              NaN           Machine Learning Engineer
# 87              NaN                         AI Engineer
# 59              3.8                         AI Engineer
# 261             4.3           Machine Learning Engineer
# 152             NaN           Machine Learning Engineer
# 156             3.8           Machine Learning Engineer
# 163             4.0           Machine Learning Engineer

# %%
df_machine_learning['salary_pa'] = df_machine_learning['salary_pa'].astype(float) / 100000

# %%
df_machine_learning.rename(columns = {'salary_pa':'salary_lpa'}, inplace = True)

# %%
df_machine_learning.head()
# Out:
#                                 company_name  \
# 0                               Recode Minds
# 1                                  Microsoft
# 2                         Club Malwa pvt ltd
# 3                            Meslova Systems
# 4  Council for Robotics & Automation (AICRA)
#
#                                             job_role job_location  salary_lpa  \
# 0       Research Associate – Artificial Intelligence    Hyderābād        5.50
# 1               Researcher - Machine Learning and AI    Bengaluru        7.00
# 2                      Senior Deep Learning Engineer       Mohali        1.35
# 3  Artificial Intelligence (AI) Researchers and D...    Hyderābād        4.00
# 4  Director - National Mission of Artificial Inte...        Delhi       48.00
#
#                                               skills  company_rating  \
# 0           TensorFlow, MATLAB, Data mining, R, Math             NaN
# 1  Machine learning, Natural language processing, AI             4.2
# 2  TensorFlow, Image processing, Azure, Big data,...             NaN
# 3   TensorFlow, React, Calculus, Encryption, English             2.8
# 4  English, Business development, Presentation sk...             3.9
#
#        standardized_job_role
# 0  Machine Learning Engineer
# 1  Machine Learning Engineer
# 2  Machine Learning Engineer
# 3  Machine Learning Engineer
# 4  Machine Learning Engineer

# %%
avg_salary_by_rating = df_machine_learning[df_machine_learning['salary_lpa'] > 0].groupby('company_rating')['salary_lpa'].mean()

def map_with_nearest_rating(row, avg_salary_by_rating):
    if row['salary_lpa'] == 0 or pd.isna(row['salary_lpa']):  
        rating = row['company_rating']
        if rating in avg_salary_by_rating:  
            return avg_salary_by_rating[rating]
        else:  
            nearest_rating = min(avg_salary_by_rating.keys(), key=lambda x: abs(x - rating))
            return avg_salary_by_rating[nearest_rating]
    return row['salary_lpa']  

df_machine_learning['salary_lpa'] = df_machine_learning.apply(
    lambda row: map_with_nearest_rating(row, avg_salary_by_rating), axis=1
)

# %%
df_machine_learning.isnull().sum()
# Out:
# company_name               0
# job_role                   0
# job_location               0
# salary_lpa                 0
# skills                     0
# company_rating           118
# standardized_job_role      0
# dtype: int64

# %% [markdown]
# ## Salary Distribution Based On Skills

# %%
df_machine_learning['skills'] = df_machine_learning['skills'].str.split(',\s*')


df_skills = df_machine_learning.explode('skills')
df_skills = df_skills.drop_duplicates().reset_index(drop = True)

# %%
import seaborn as sns
# Calculate the frequency of each skill
skill_counts = df_skills['skills'].value_counts()

# Get the top 10 most frequent skills
top_skills = skill_counts.head(10).index

# Filter the DataFrame to keep only rows with the top 10 skills


df_top_skills = df_skills[df_skills['skills'].isin(top_skills)]

# %%
import warnings
import pandas as pd
import matplotlib.pyplot as plt

warnings.simplefilter(action='ignore', category=UserWarning)
pd.options.mode.use_inf_as_na = True
plt.figure(figsize=(12, 6))
# sns.swarmplot(x='skills', y='salary_pa', data=df_top_skills, palette="Set2")
sns.swarmplot(x='skills', y='salary_lpa', data=df_top_skills,palette="Set2",hue="skills",legend=False)

plt.title("Salary Distribution by Top 10 Skills (Swarm Plot)", fontsize=14)
plt.xlabel("Skills", fontsize=12)
plt.ylabel("Salary", fontsize=12)
plt.xticks(rotation=45, ha="right")
plt.show()
# Out:
# C:\Users\rhyth\AppData\Local\Temp\ipykernel_17592\3667392867.py:6: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   pd.options.mode.use_inf_as_na = True
# C:\Users\rhyth\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\rhyth\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### Analysing the most asked Skills

# %%
all_skills = [skill for sublist in df_machine_learning['skills'].dropna() for skill in sublist]

# %%
df_machine_learning.head()
# Out:
#                                 company_name  \
# 0                               Recode Minds
# 1                                  Microsoft
# 2                         Club Malwa pvt ltd
# 3                            Meslova Systems
# 4  Council for Robotics & Automation (AICRA)
#
#                                             job_role job_location  salary_lpa  \
# 0       Research Associate – Artificial Intelligence    Hyderābād        5.50
# 1               Researcher - Machine Learning and AI    Bengaluru        7.00
# 2                      Senior Deep Learning Engineer       Mohali        1.35
# 3  Artificial Intelligence (AI) Researchers and D...    Hyderābād        4.00
# 4  Director - National Mission of Artificial Inte...        Delhi       48.00
#
#                                               skills  company_rating  \
# 0         [TensorFlow, MATLAB, Data mining, R, Math]             NaN
# 1  [Machine learning, Natural language processing...             4.2
# 2  [TensorFlow, Image processing, Azure, Big data...             NaN
# 3  [TensorFlow, React, Calculus, Encryption, Engl...             2.8
# 4  [English, Business development, Presentation s...             3.9
#
#        standardized_job_role
# 0  Machine Learning Engineer
# 1  Machine Learning Engineer
# 2  Machine Learning Engineer
# 3  Machine Learning Engineer
# 4  Machine Learning Engineer

# %%
from collections import Counter


skill_counts = Counter(all_skills)


skill_df = pd.DataFrame(skill_counts.items(), columns=['Skill', 'Count'])


skill_df = skill_df.sort_values(by='Count', ascending=False)
print(skill_df)
# Out:
#                  Skill  Count
# 0           TensorFlow    165
# 5     Machine learning    152
# 8     Image processing     93
# 9                Azure     87
# 15             English     65
# ..                 ...    ...
# 109  Robot programming      1
# 108  Technical writing      1
# 106    Service writing      1
# 103        Objective-C      1
# 178     Data analytics      1
#
# [179 rows x 2 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt


top_skills = skill_df.head(25)

plt.figure(figsize=(12, 6))
sns.barplot(x=top_skills['Count'], y=top_skills['Skill'], palette="Blues_r")

plt.title("Top 25 Most In-Demand Skills for Machine Learning Roles", fontsize=14)
plt.xlabel("Number of Job Listings", fontsize=12)
plt.ylabel("Skills", fontsize=12)
plt.show()

# %%
from wordcloud import WordCloud

wordcloud = WordCloud(width=800, height=400, background_color="white").generate_from_frequencies(skill_counts)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# ### Analysing High Paying Jobs

# %%
top_companies = df_machine_learning.groupby('company_name')['salary_lpa'].mean().reset_index()


top_companies = top_companies.sort_values(by='salary_lpa', ascending=False)


print(top_companies.head(10))
# Out:
#                                   company_name  salary_lpa
# 1                             ADCI - Karnataka        48.0
# 186                         Openspace Services        48.0
# 291                                      adyog        48.0
# 178                                Nio Digital        48.0
# 99                            Griffyn Robotech        48.0
# 52   Council for Robotics & Automation (AICRA)        48.0
# 238                                     Splunk        47.5
# 216                                       Real        43.0
# 48                Code Tree Software Solutions        42.0
# 153                                  Markovate        42.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt


top_10 = top_companies.head(25)

plt.figure(figsize=(12, 8))
sns.barplot(x=top_10['salary_lpa'], y=top_10['company_name'], palette="coolwarm")

plt.title("Top 50 Companies by Average Salary", fontsize=20)
plt.xlabel("Average Salary (LPA)", fontsize=18)
plt.ylabel("Company", fontsize=18)
plt.show()

# %% [markdown]
# ### Salary VS Location

# %%
salary_by_location = df_machine_learning.groupby('job_location')['salary_lpa'].sum()


top_locations = salary_by_location.sort_values(ascending=False).head(25)


plt.figure(figsize=(12, 8))
sns.barplot(x=top_locations.index, y=top_locations.values, palette='viridis')


plt.xlabel('Job Location')
plt.ylabel('Total Salary (LPA)')
plt.title('Top 25 Locations by Total Salary')


plt.xticks(rotation=45, ha='right')


plt.tight_layout()
plt.show()

# %% [markdown]
# ### No of jobs VS Location

# %%
job_count_by_location = df_machine_learning['job_location'].value_counts()


top_locations = job_count_by_location.head(25)

# %%
plt.figure(figsize=(12, 8))
sns.barplot(x=top_locations.index, y=top_locations.values, palette='viridis')


plt.xlabel('Job Location')
plt.ylabel('Number of Job Postings')
plt.title('Top 25 Locations with Most Job Postings')


plt.xticks(rotation=45, ha='right')


plt.tight_layout()
plt.show()

# %% [markdown]
# ### Highest Paying Job Roles

# %%
top_roles_by_salary = df_machine_learning[['job_role', 'salary_lpa']].sort_values(by='salary_lpa', ascending=False).head(25)


plt.figure(figsize=(12, 8))
sns.barplot(x='salary_lpa', y='job_role', data=top_roles_by_salary, palette='coolwarm')


plt.xlabel('Salary (LPA)')
plt.ylabel('Job Role')
plt.title('Top 25 Highest Paying Job Roles')


plt.tight_layout()
plt.show()

# %% [markdown]
# ### Salary Distribution Curves

# %%
import matplotlib.pyplot as plt
import seaborn as sns


df_blockchain_clean = df_machine_learning[df_machine_learning['salary_lpa'] > 0]


plt.figure(figsize=(12, 6))
sns.boxplot(
    data=df_blockchain_clean,
    x='standardized_job_role',
    y='salary_lpa',
    palette='viridis'
)
plt.title('Salary Distribution Across Job Roles', fontsize=16)
plt.xlabel('Job Roles', fontsize=14)
plt.ylabel('Salary (lakhs per annum)', fontsize=14)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Company Rating VS Average Salary

# %%
rating_avg_salary = df_machine_learning.groupby('company_rating')['salary_lpa'].mean()
# Step 1a: Map the. average salary to a diction
plt.figure(figsize=(8, 5))
plt.scatter(rating_avg_salary.index, rating_avg_salary.values, color='skyblue', s=100)
plt.title('Company Rating vs. Average Salary')
plt.xlabel('Company Rating')
plt.ylabel('Average Salary')
plt.grid(alpha=0.5)
plt.show()

# %% [markdown]
# ### Remote VS Onsite

# %%
location_counts = df_machine_learning[df_machine_learning['job_location'] != 'India']['job_location'].value_counts()


top_locations = location_counts.head(6).index


df_machine_learning['job_location_grouped'] = df_machine_learning['job_location'].apply(lambda x: x if x in top_locations else 'Other')


location_grouped_counts = df_machine_learning['job_location_grouped'].value_counts()


plt.figure(figsize=(8, 8))
plt.pie(location_grouped_counts, labels=location_grouped_counts.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette("Set2", len(location_grouped_counts)))


plt.title("Distribution of Job Locations (Top 6 Locations + Other)", fontsize=14)


plt.show()
